# %% [markdown]
# # Cleaning dataframe
# 1. Read previous dataframe

# %%
import pandas as pd

df = pd.read_pickle("../data/raw/raw_df.pkl")
df
# Out:
#               League             Team                  Name  Age  \
# 0     premier-league  Manchester City  Gianluigi Donnarumma   27
# 1     premier-league  Manchester City        James Trafford   23
# 3     premier-league  Manchester City        Josko Gvardiol   24
# 4     premier-league  Manchester City            Marc Guéhi   25
# 5     premier-league  Manchester City            Rúben Dias   28
# ...              ...              ...                   ...  ...
# 1014         la-liga      Real Oviedo      Thiago Fernández   22
# 1015         la-liga      Real Oviedo          Ilyas Chaira   25
# 1016         la-liga      Real Oviedo           Ovie Ejaria   28
# 1018         la-liga      Real Oviedo        Federico Viñas   27
# 1019         la-liga      Real Oviedo         Thiago Borbas   24
#
#             Position Market Value  Matches Played  Matches Played (Per90)  \
# 0         Goalkeeper      €45.00m            28.0                     NaN
# ...

# %% [markdown]
# 2. Data Type Conversion

# %%
from scripts.utils import *
print(money_to_int("€1m"))
# Out:
# 1000000.0

# %% [markdown]
# 3. Output dataframe for next step

# %%
df.to_pickle("../data/clean/clean_df.pkl")
